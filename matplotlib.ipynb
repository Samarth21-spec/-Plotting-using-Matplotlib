# %%
import pandas as pd
re=pd.read_csv("s1.csv")

# %%
re.tail()
# Out:
#     Unnamed: 0                             mobilename   price  Rating:
# 19          19     MOTOROLA G60 (Soft Silver, 128 GB)  14,999      4.2
# 20          20  REDMI 9i Sport (Metallic Blue, 64 GB)   8,799      4.4
# 21          21      REDMI 10 (Caribbean Green, 64 GB)  10,999      4.4
# 22          22     realme C11 2021 (Cool Grey, 64 GB)   8,999      4.3
# 23          23    MOTOROLA G60 (Dynamic Gray, 128 GB)  14,999      4.2

# %%
re.head()
# Out:
#    Unnamed: 0                             mobilename   price  Rating:
# 0           0   SAMSUNG Galaxy F12 (Sky Blue, 64 GB)   9,499      4.3
# 1           1  SAMSUNG Galaxy F12 (Sea Green, 64 GB)   9,499      4.3
# 2           2    REDMI 9i Sport (Coral Green, 64 GB)   8,799      4.4
# 3           3                           Good One AIR   1,260      4.2
# 4           4         realme 9i (Prism Black, 64 GB)  12,999      4.5

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24 non-null     int64
#  1   mobilename  24 non-null     object
#  2   price       24 non-null     object
#  3   Rating:     24 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 896.0+ bytes

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.bar(re["price"],re["mobilename"],width=0.5)
plt.figure(figsize=(3,6))
plt.show()

# %%
plt.bar(re["Rating:"],re["mobilename"],width=0.4)
plt.figure(figsize=(18,16))
plt.show()
